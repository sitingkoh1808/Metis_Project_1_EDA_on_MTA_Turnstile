# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import datetime
from functools import partial, reduce

#merge 4 dataframe to get an 1mth data 

df1 = pd.read_csv('http://web.mta.info/developers/data/nyct/turnstile/turnstile_200829.txt')
df2 = pd.read_csv('http://web.mta.info/developers/data/nyct/turnstile/turnstile_200815.txt')
df3 = pd.read_csv('http://web.mta.info/developers/data/nyct/turnstile/turnstile_200808.txt')
df4 = pd.read_csv('http://web.mta.info/developers/data/nyct/turnstile/turnstile_200801.txt')
dfs = [df1, df2, df3, df4]

merge = partial(pd.merge, on=['C/A','UNIT','SCP','STATION','LINENAME','DIVISION','DATE','TIME', 'DESC','ENTRIES','EXITS                                                               '], how='outer')
mta = reduce(merge, dfs)
mta
# Out:
#           C/A  UNIT       SCP        STATION LINENAME DIVISION        DATE  \
# 0        A002  R051  02-00-00          59 ST  NQR456W      BMT  08/22/2020
# 1        A002  R051  02-00-00          59 ST  NQR456W      BMT  08/22/2020
# 2        A002  R051  02-00-00          59 ST  NQR456W      BMT  08/22/2020
# 3        A002  R051  02-00-00          59 ST  NQR456W      BMT  08/22/2020
# 4        A002  R051  02-00-00          59 ST  NQR456W      BMT  08/22/2020
# ...       ...   ...       ...            ...      ...      ...         ...
# 838424  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  07/31/2020
# 838425  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  07/31/2020
# 838426  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  07/31/2020
# 838427  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  07/31/2020
# 838428  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  07/31/2020
#
#             TIME     DESC  ENTRIES  \
# 0       00:00:00  REGULAR  7447810
# 1       04:00:00  REGULAR  7447812
# 2       08:00:00  REGULAR  7447824
# 3       12:00:00  REGULAR  7447852
# 4       16:00:00  REGULAR  7447937
# ...          ...      ...      ...
# 838424  12:59:32  REGULAR     5554
# 838425  13:00:00  REGULAR     5554
# 838426  13:11:06  REGULAR     5554
# 838427  17:00:00  REGULAR     5554
# 838428  21:00:00  REGULAR     5554
#
#         EXITS
# 0                                                 2532191
# 1                                                 2532197
# 2                                                 2532208
# 3                                                 2532248
# 4                                                 2532276
# ...                                                   ...
# 838424                                                538
# 838425                                                538
# 838426                                                538
# 838427                                                538
# 838428                                                538
#
# [838429 rows x 11 columns]

# %%
mta.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 838429 entries, 0 to 838428
# Data columns (total 11 columns):
#  #   Column                                                                Non-Null Count   Dtype
# ---  ------                                                                --------------   -----
#  0   C/A                                                                   838429 non-null  object
#  1   UNIT                                                                  838429 non-null  object
#  2   SCP                                                                   838429 non-null  object
#  3   STATION                                                               838429 non-null  object
#  4   LINENAME                                                              838429 non-null  object
#  5   DIVISION                                                              838429 non-null  object
#  6   DATE                                                                  838429 non-null  object
#  7   TIME                                                                  838429 non-null  object
#  8   DESC                                                                  838429 non-null  object
#  9   ENTRIES                                                               838429 non-null  int64
#  10  EXITS                                                                 838429 non-null  int64
# dtypes: int64(2), object(9)
# memory usage: 76.8+ MB

# %%
def preprocess(mta):
    
    # Standardize column name 
    mta.columns = mta.columns.str.strip()
        
    # Create DATETIME column from 'DATE' and 'TIME' cols
    mta['DATETIME'] = pd.to_datetime(mta.DATE + " " + mta.TIME, 
                                    format="%m/%d/%Y %H:%M:%S")
    
    # Create 'DOW' (Day of Week) column from 'DATETIME'
    mta['DOW'] = mta[['DATETIME']]\
    .apply(lambda x: datetime.datetime.strftime(x['DATETIME'], '%A'), axis=1)
       
    # Drop unnecessary columns
    mta = mta.drop(['LINENAME', 'DIVISION', 'DATE', 'DESC','TIME'], axis=1) 

    return mta

# %%
mta2 = preprocess(mta)
mta2
# Out:
#           C/A  UNIT       SCP        STATION  ENTRIES    EXITS  \
# 0        A002  R051  02-00-00          59 ST  7447810  2532191
# 1        A002  R051  02-00-00          59 ST  7447812  2532197
# 2        A002  R051  02-00-00          59 ST  7447824  2532208
# 3        A002  R051  02-00-00          59 ST  7447852  2532248
# 4        A002  R051  02-00-00          59 ST  7447937  2532276
# ...       ...   ...       ...            ...      ...      ...
# 838424  TRAM2  R469  00-05-01  RIT-ROOSEVELT     5554      538
# 838425  TRAM2  R469  00-05-01  RIT-ROOSEVELT     5554      538
# 838426  TRAM2  R469  00-05-01  RIT-ROOSEVELT     5554      538
# 838427  TRAM2  R469  00-05-01  RIT-ROOSEVELT     5554      538
# 838428  TRAM2  R469  00-05-01  RIT-ROOSEVELT     5554      538
#
#                   DATETIME       DOW
# 0      2020-08-22 00:00:00  Saturday
# 1      2020-08-22 04:00:00  Saturday
# 2      2020-08-22 08:00:00  Saturday
# 3      2020-08-22 12:00:00  Saturday
# 4      2020-08-22 16:00:00  Saturday
# ...                    ...       ...
# 838424 2020-07-31 12:59:32    Friday
# 838425 2020-07-31 13:00:00    Friday
# 838426 2020-07-31 13:11:06    Friday
# 838427 2020-07-31 17:00:00    Friday
# 838428 2020-07-31 21:00:00    Friday
#
# [838429 rows x 8 columns]

# %%
# Drop Nulls created by previous cell
print("prior shape: ", mta2.shape)
mta2.dropna(how='any', inplace=True)
print("post shape: ", mta2.shape)
# Out:
# prior shape:  (838429, 8)
# post shape:  (838429, 8)

# %%
# Check for duplicates for a given turnstile for a given datetime
(mta2
 .groupby(['STATION', 'DATETIME','C/A','UNIT','SCP'])
 .ENTRIES.count()
 .reset_index()
 .sort_values("ENTRIES", ascending=False)).head(5)

# Remove duplicates
print("prior shape: ", mta2.shape)
mta2.drop_duplicates(subset=["STATION", "DATETIME",'C/A','UNIT','SCP'], inplace=True)
print("post shape: ", mta2.shape)
# Out:
# prior shape:  (838429, 8)
# post shape:  (838412, 8)

# %%
mta2 = mta2.sort_values(['STATION','DATETIME','C/A', 'UNIT', 'SCP'])
mta2
# Out:
#          C/A  UNIT       SCP    STATION    ENTRIES      EXITS  \
# 663935  H007  R248  00-00-00       1 AV   15459169   17334477
# 663977  H007  R248  00-00-01       1 AV   61144410   38179100
# 664019  H007  R248  00-03-00       1 AV  370865984  388060589
# 664061  H007  R248  00-03-01       1 AV    2606562    1129443
# 664103  H007  R248  00-03-02       1 AV    6635849     560183
# ...      ...   ...       ...        ...        ...        ...
# 191134  R419  R326  00-00-01  ZEREGA AV     208295     335195
# 191176  R419  R326  00-03-00  ZEREGA AV    1105299     496941
# 191218  R419  R326  00-03-01  ZEREGA AV    1137379     213443
# 191260  R419  R326  00-05-00  ZEREGA AV        229          0
# 191302  R419  R326  00-05-01  ZEREGA AV         39        167
#
#                   DATETIME       DOW
# 663935 2020-07-25 00:00:00  Saturday
# 663977 2020-07-25 00:00:00  Saturday
# 664019 2020-07-25 00:00:00  Saturday
# 664061 2020-07-25 00:00:00  Saturday
# 664103 2020-07-25 00:00:00  Saturday
# ...                    ...       ...
# 191134 2020-08-28 21:00:00    Friday
# 191176 2020-08-28 21:00:00    Friday
# 191218 2020-08-28 21:00:00    Friday
# 191260 2020-08-28 21:00:00    Friday
# 191302 2020-08-28 21:00:00    Friday
#
# [838412 rows x 8 columns]

# %%
# Create diff columns to take entries/exits for given time interval
mta2['entry_diff'] = mta2.groupby(['STATION','C/A', 'UNIT', 'SCP'], as_index=False)['ENTRIES'].diff().tolist()
mta2['exit_diff'] = mta2.groupby(['STATION','C/A', 'UNIT', 'SCP'], as_index=False)['EXITS'].diff().tolist()

# %%
mta2.head()
# Out:
#          C/A  UNIT       SCP STATION    ENTRIES      EXITS   DATETIME  \
# 663935  H007  R248  00-00-00    1 AV   15459169   17334477 2020-07-25
# 663977  H007  R248  00-00-01    1 AV   61144410   38179100 2020-07-25
# 664019  H007  R248  00-03-00    1 AV  370865984  388060589 2020-07-25
# 664061  H007  R248  00-03-01    1 AV    2606562    1129443 2020-07-25
# 664103  H007  R248  00-03-02    1 AV    6635849     560183 2020-07-25
#
#              DOW  entry_diff  exit_diff
# 663935  Saturday         NaN        NaN
# 663977  Saturday         1.0       21.0
# 664019  Saturday         6.0      117.0
# 664061  Saturday        20.0      230.0
# 664103  Saturday        40.0      304.0

# %%
# Drop Nulls created by previous groupby().diff()
print("prior shape: ", mta2.shape)
mta2.dropna(how='any', inplace=True)
print("post shape: ", mta2.shape)
# Out:
# prior shape:  (838412, 10)
# post shape:  (833449, 10)

# %%
# ASSUMPTION: All negative actuals for entries and exits will be dropped from dataset since values should be accumulative 
len_entry_diffs = mta2['entry_diff'].shape[0]
len_exit_diffs = mta2['exit_diff'].shape[0]

negative_entries = mta2[mta2['entry_diff'] < 0].shape[0] / len_entry_diffs
negative_exits = mta2[mta2['exit_diff'] < 0].shape[0] / len_exit_diffs

print('negative_entries: ', negative_entries)
print('negative_exits: ', negative_exits)

## Drop negatives
print("prior shape: ", mta2.shape)
mta2 = mta2.loc[ (mta2['entry_diff'] > 0) & (mta2['exit_diff'] > 0) ]
print("post shape: ", mta2.shape)
# Out:
# negative_entries:  0.007792918342934001
# negative_exits:  0.006305124848671005
# prior shape:  (833449, 10)
# post shape:  (597781, 10)

# %%
# Create Outlier Threshold based on total seconds in a day: Assuming that each sec cannot have more than 1 person doing turnstile
threshold_entry = 86400
threshold_exit = 86400

## Drop outliers
print("prior shape: ", mta2.shape)
mta2 = mta2[(mta2['entry_diff'] < threshold_entry) & (mta2['exit_diff'] < threshold_exit)]
print("post shape: ", mta2.shape)
# Out:
# prior shape:  (597781, 10)
# post shape:  (597767, 10)

# %%
# Create 'TOTAL_TRAFFIC" = exits + entries. This will be our ranking metric

mta2['TRAFFIC'] = mta2['entry_diff'] + mta2['exit_diff']
print("post shape: ", mta2.shape)
mta2.sort_values('TRAFFIC', ascending=False).head()
# Out:
# post shape:  (597767, 11)
#           C/A  UNIT       SCP          STATION  ENTRIES   EXITS  \
# 335486  PTH03  R552  00-00-03   JOURNAL SQUARE   474367   91531
# 335727  PTH03  R552  00-00-09   JOURNAL SQUARE   139377  705156
# 336128  PTH03  R552  00-01-08   JOURNAL SQUARE      627     476
# 335805  PTH03  R552  00-01-00   JOURNAL SQUARE    18539   60931
# 485835   N094  R029  01-03-04  WORLD TRADE CTR   477023  160658
#
#                   DATETIME     DOW  entry_diff  exit_diff  TRAFFIC
# 335486 2020-08-14 23:27:41  Friday     42192.0    33163.0  75355.0
# 335727 2020-08-14 21:21:37  Friday     42050.0    33037.0  75087.0
# 336128 2020-08-14 18:21:20  Friday     41843.0    32827.0  74670.0
# 335805 2020-08-14 15:31:00  Friday     41593.0    32619.0  74212.0
# 485835 2020-08-03 20:00:00  Monday     49152.0        2.0  49154.0

# %%
# Force time intervals to 4-hour frequency
mta2['TIME'] = mta2['DATETIME'].apply(lambda x: x.time())
mta2 = mta2.groupby(['C/A',
                     'UNIT', 
                     'SCP', 
                     'STATION',
                     pd.Grouper(key='DATETIME', freq='4H'), 
                     'DOW', 
                     'TIME']).sum().reset_index()

# Shift time intervals back 4 hours to make DOW accurate reading of day
mta2['DATETIME'] = mta2['DATETIME'].apply(lambda x: x - datetime.timedelta(hours=4))

print("UNIQUE TIMES: ", mta2['TIME'].unique())
# Out:
# UNIQUE TIMES:  [datetime.time(4, 0) datetime.time(8, 0) datetime.time(12, 0) ...
#  datetime.time(12, 30, 48) datetime.time(12, 59, 32)
#  datetime.time(13, 11, 6)]

# %%
# taken from preprocess()
mta2['DOW'] = mta2['DATETIME'].apply(lambda x: datetime.datetime.strftime(x, '%A'))
mta2
# Out:
#           C/A  UNIT       SCP        STATION            DATETIME       DOW  \
# 0        A002  R051  02-00-00          59 ST 2020-07-25 00:00:00  Saturday
# 1        A002  R051  02-00-00          59 ST 2020-07-25 04:00:00  Saturday
# 2        A002  R051  02-00-00          59 ST 2020-07-25 08:00:00  Saturday
# 3        A002  R051  02-00-00          59 ST 2020-07-25 12:00:00  Saturday
# 4        A002  R051  02-00-00          59 ST 2020-07-25 16:00:00  Saturday
# ...       ...   ...       ...            ...                 ...       ...
# 597762  TRAM2  R469  00-05-01  RIT-ROOSEVELT 2020-08-01 16:00:00  Saturday
# 597763  TRAM2  R469  00-05-01  RIT-ROOSEVELT 2020-08-01 20:00:00  Saturday
# 597764  TRAM2  R469  00-05-01  RIT-ROOSEVELT 2020-08-02 04:00:00    Sunday
# 597765  TRAM2  R469  00-05-01  RIT-ROOSEVELT 2020-08-02 08:00:00    Sunday
# 597766  TRAM2  R469  00-05-01  RIT-ROOSEVELT 2020-08-02 12:00:00    Sunday
#
#             TIME  ENTRIES    EXITS  entry_diff  exit_diff  TRAFFIC
# 0       04:00:00  7436572  2527900       134.0       14.0    148.0
# 1       08:00:00  7436581  2527907        58.0       18.0     76.0
# 2       12:00:00  7436611  2527942        40.0       59.0     99.0
# 3       16:00:00  7436681  2527962         9.0       31.0     40.0
# 4       20:00:00  7436825  2527978         1.0        1.0      2.0
# ...          ...      ...      ...         ...        ...      ...
# 597762  21:00:00     5554      538       165.0        9.0    174.0
# 597763  01:00:00     5554      538       161.0        1.0    162.0
# 597764  09:00:00     5554      538       174.0        1.0    175.0
# 597765  13:00:00     5554      538       186.0        4.0    190.0
# 597766  17:00:00     5554      538       189.0        7.0    196.0
#
# [597767 rows x 12 columns]

# %%
mta2 = mta2.drop(['C/A','UNIT', 'SCP'], axis=1) 
mta2
# Out:
#               STATION            DATETIME       DOW      TIME  ENTRIES  \
# 0               59 ST 2020-07-25 00:00:00  Saturday  04:00:00  7436572
# 1               59 ST 2020-07-25 04:00:00  Saturday  08:00:00  7436581
# 2               59 ST 2020-07-25 08:00:00  Saturday  12:00:00  7436611
# 3               59 ST 2020-07-25 12:00:00  Saturday  16:00:00  7436681
# 4               59 ST 2020-07-25 16:00:00  Saturday  20:00:00  7436825
# ...               ...                 ...       ...       ...      ...
# 597762  RIT-ROOSEVELT 2020-08-01 16:00:00  Saturday  21:00:00     5554
# 597763  RIT-ROOSEVELT 2020-08-01 20:00:00  Saturday  01:00:00     5554
# 597764  RIT-ROOSEVELT 2020-08-02 04:00:00    Sunday  09:00:00     5554
# 597765  RIT-ROOSEVELT 2020-08-02 08:00:00    Sunday  13:00:00     5554
# 597766  RIT-ROOSEVELT 2020-08-02 12:00:00    Sunday  17:00:00     5554
#
#           EXITS  entry_diff  exit_diff  TRAFFIC
# 0       2527900       134.0       14.0    148.0
# 1       2527907        58.0       18.0     76.0
# 2       2527942        40.0       59.0     99.0
# 3       2527962         9.0       31.0     40.0
# 4       2527978         1.0        1.0      2.0
# ...         ...         ...        ...      ...
# 597762      538       165.0        9.0    174.0
# 597763      538       161.0        1.0    162.0
# 597764      538       174.0        1.0    175.0
# 597765      538       186.0        4.0    190.0
# 597766      538       189.0        7.0    196.0
#
# [597767 rows x 9 columns]

# %%
# Focus on TRAFFIC
mta2.drop(['ENTRIES', 'EXITS', 'entry_diff', 'exit_diff'], axis=1, inplace=True)
mta2.head()
# Out:
#   STATION            DATETIME       DOW      TIME  TRAFFIC
# 0   59 ST 2020-07-25 00:00:00  Saturday  04:00:00    148.0
# 1   59 ST 2020-07-25 04:00:00  Saturday  08:00:00     76.0
# 2   59 ST 2020-07-25 08:00:00  Saturday  12:00:00     99.0
# 3   59 ST 2020-07-25 12:00:00  Saturday  16:00:00     40.0
# 4   59 ST 2020-07-25 16:00:00  Saturday  20:00:00      2.0

# %%
#Focus on Top Stations 
mta2_station = mta2.groupby(['STATION'])['TRAFFIC'].sum().sort_values(ascending = False).head(10)
mta2_station = pd.DataFrame(mta2_station.reset_index())
mta2_station
# Out:
#            STATION    TRAFFIC
# 0   34 ST-PENN STA  1863905.0
# 1  34 ST-HERALD SQ  1494996.0
# 2           125 ST  1416187.0
# 3            86 ST  1273737.0
# 4   14 ST-UNION SQ  1255135.0
# 5  42 ST-PORT AUTH  1198266.0
# 6  GRD CNTRL-42 ST  1195471.0
# 7            23 ST  1096553.0
# 8    FLUSHING-MAIN  1054372.0
# 9        FULTON ST  1019065.0

# %%
#Plot graph for TOP 10 STATIONS BASED ON MONTHLY RIDERSHIP - AUGUST 2020
plt.figure(figsize=(15,8))
plt.title('TOP 10 STATIONS BASED ON MONTHLY RIDERSHIP - AUGUST 2020',family='CALIBRI',fontsize = 20,loc='CENTER',color='black');
sns.barplot(data = mta2_station, y = mta2_station.STATION, x = mta2_station.TRAFFIC)
plt.show()

# %%
#Focus on Day of Week 
cats = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
mta2_DOW = mta2.groupby(['DOW'])['TRAFFIC'].sum().reset_index()
mta2_DOW['DOW'] = pd.Categorical(mta2_DOW['DOW'], categories=cats, ordered=True)
mta2_DOW = mta2_DOW.sort_values('DOW')
mta2_DOW
# Out:
#          DOW     TRAFFIC
# 1     Monday  11215688.0
# 5    Tuesday  11113156.0
# 6  Wednesday  10836334.0
# 4   Thursday  10949318.0
# 0     Friday  11817270.0
# 2   Saturday  12138628.0
# 3     Sunday  12002600.0

# %%
#Plot graph for MONTHLY RIDERSHIP FOR AUGUST 2020
plt.figure(figsize=(16,8))
plt.title('WEEKLY RIDERSHIP FOR AUGUST 2020',family='CALIBRI',fontsize = 20,loc='CENTER',color='black');
sns.lineplot(data = mta2_DOW, x = mta2_DOW.DOW, y = mta2_DOW.TRAFFIC)
plt.show()

# %%
#Checking Data against graph 
mta2_DOW.groupby(['DOW']).sum().sort_values(by = 'TRAFFIC', ascending = False)
# Out:
#               TRAFFIC
# DOW
# Saturday   12138628.0
# Sunday     12002600.0
# Friday     11817270.0
# Monday     11215688.0
# Tuesday    11113156.0
# Thursday   10949318.0
# Wednesday  10836334.0

# %%
# Plot graph for MONTHLY TRAFFIC FOR TOP 3 STATIONS
mta2_STATION_DOW = mta2.groupby(['STATION', 'DOW'])['TRAFFIC'].sum().sort_values(ascending = False).reset_index()
mta2_DOW__STATIONS3 = mta2_STATION_DOW[mta2_STATION_DOW['STATION'].isin(['34 ST-PENN STA', '34 ST-HERALD SQ', '125 ST'])]

cats = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
mta2_DOW__STATIONS3['DOW'] = pd.Categorical(mta2_DOW__STATIONS3['DOW'], categories=cats, ordered=True)

plt.figure(figsize=(16,8))
plt.title('MONTHLY TRAFFIC FOR TOP 3 STATIONS',family='CALIBRI',fontsize = 20,loc='CENTER',color='black');
sns.lineplot(data = mta2_DOW__STATIONS3, x = mta2_DOW__STATIONS3.DOW, y = mta2_DOW__STATIONS3.TRAFFIC, hue = 'STATION')
plt.show()
# Out:
# <ipython-input-23-ceeae7df84a2>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mta2_DOW__STATIONS3['DOW'] = pd.Categorical(mta2_DOW__STATIONS3['DOW'], categories=cats, ordered=True)
